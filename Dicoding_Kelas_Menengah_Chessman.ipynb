# %%
# !wget --no-check-certificate https://dicodingacademy.blob.core.windows.net/picodiploma/ml_pengembangan_academy/Chessman-image-dataset.zip \
-O /tmp/Chessman-image-dataset.zip
# Out:
# --2021-06-08 02:38:29--  https://dicodingacademy.blob.core.windows.net/picodiploma/ml_pengembangan_academy/Chessman-image-dataset.zip
# Resolving dicodingacademy.blob.core.windows.net (dicodingacademy.blob.core.windows.net)... 52.239.197.36
# Connecting to dicodingacademy.blob.core.windows.net (dicodingacademy.blob.core.windows.net)|52.239.197.36|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 60684125 (58M) [application/zip]
# Saving to: ‘/tmp/Chessman-image-dataset.zip’
#
# /tmp/Chessman-image 100%[===================>]  57.87M   710KB/s    in 65s
#
# 2021-06-08 02:39:36 (909 KB/s) - ‘/tmp/Chessman-image-dataset.zip’ saved [60684125/60684125]

# %%
import os
import zipfile
local_zip = '/tmp/Chessman-image-dataset.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('/tmp')
zip_ref.close()

# %%
os.listdir('/tmp/Chessman-image-dataset/Chess')
# Out:
# ['Queen', 'Rook', 'King', 'Pawn', 'Bishop', 'Knight']

# %%
print('total pawn images :', len(os.listdir('/tmp/Chessman-image-dataset/Chess/Pawn')))
print('total King images :', len(os.listdir('/tmp/Chessman-image-dataset/Chess/King')))
print('total Knight images :', len(os.listdir('/tmp/Chessman-image-dataset/Chess/Knight')))
# Out:
# total pawn images : 107
# total King images : 76
# total Knight images : 106

# %%
from keras.preprocessing import image
# import matplotlib.pyplot as plt
# import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline
img = image.load_img('/tmp/Chessman-image-dataset/Chess/King/00000145.png')
imgplot = plt.imshow(img)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
 
train_dir = os.path.join('/tmp/Chessman-image-dataset/Chess')
train_datagen = ImageDataGenerator(rescale=1./255,
    rotation_range=20,
    zoom_range=0.2,
    shear_range=0.2,
    fill_mode = 'nearest',
    validation_split=0.1) # set validation split

# %%
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(150, 150),
    batch_size=8,
    class_mode='categorical',
    subset='training') # set as training data
validation_generator = train_datagen.flow_from_directory(
    train_dir, # same directory as training data
    target_size=(150, 150),
    batch_size=16,
    class_mode='categorical',
    subset='validation')
# Out:
# Found 499 images belonging to 6 classes.
# Found 52 images belonging to 6 classes.

# %%
import tensorflow as tf
model = tf.keras.models.Sequential([
    # Note the input shape is the desired size of the image 150x150 with 3 bytes color
    tf.keras.layers.Conv2D(64, (3,3), activation='relu', input_shape=(150, 150, 3)),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Dropout(0.4),  
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'), 
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Dropout(0.4),  
    # Flatten the results to feed into a DNN
    tf.keras.layers.Flatten(), 
    # 512 neuron hidden layer
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(256, activation='relu'),
    # Only 1 output neuron. It will contain a value from 0-1 where 0 for 1 class ('cats') and 1 for the other ('dogs')
    tf.keras.layers.Dense(6, activation='softmax')  
])

# %%
model.compile(optimizer=tf.optimizers.Adam(),
              loss='categorical_crossentropy',
              metrics = ['accuracy'])

# %%
history = model.fit(train_generator,
                              validation_data=validation_generator,
                              epochs=50,
                              verbose=2)
# Out:
# Epoch 1/50
# 63/63 - 33s - loss: 1.8638 - accuracy: 0.1563 - val_loss: 1.7856 - val_accuracy: 0.1923
# Epoch 2/50
# 63/63 - 31s - loss: 1.7864 - accuracy: 0.1964 - val_loss: 1.7820 - val_accuracy: 0.2115
# Epoch 3/50
# 63/63 - 31s - loss: 1.7812 - accuracy: 0.2064 - val_loss: 1.7800 - val_accuracy: 0.1538
# Epoch 4/50
# 63/63 - 31s - loss: 1.7607 - accuracy: 0.2405 - val_loss: 1.7486 - val_accuracy: 0.3462
# Epoch 5/50
# 63/63 - 31s - loss: 1.7234 - accuracy: 0.2685 - val_loss: 1.7042 - val_accuracy: 0.3269
# Epoch 6/50
# 63/63 - 31s - loss: 1.6807 - accuracy: 0.3066 - val_loss: 1.6698 - val_accuracy: 0.3269
# Epoch 7/50
# 63/63 - 32s - loss: 1.5845 - accuracy: 0.3747 - val_loss: 1.6999 - val_accuracy: 0.3654
# Epoch 8/50
# 63/63 - 31s - loss: 1.5434 - accuracy: 0.3747 - val_loss: 1.6169 - val_accuracy: 0.3269
# Epoch 9/50
# 63/63 - 31s - loss: 1.4896 - accuracy: 0.4228 - val_loss: 1.6989 - val_accuracy: 0.2500
# Epoch 10/50
# 63/63 - 31s - loss: 1.4355 - accuracy: 0.4289 - val_loss: 1.5619 - val_accuracy: 0.3462
# Epoch 11/50
# 63/63 - 31s - loss: 1.3685 - accuracy: 0.4489 - val_loss: 1.4421 - val_accuracy: 0.4038
# Epoch 12/50
# 63/63 - 31s - loss: 1.3524 - accuracy: 0.4689 - val_loss: 1.5942 - val_accuracy: 0.2885
# Epoch 13/50
# 63/63 - 31s - loss: 1.3082 - accuracy: 0.4830 - val_loss: 1.5579 - val_accuracy: 0.3846
# Epoch 14/50
# 63/63 - 31s - loss: 1.2559 - accuracy: 0.4990 - val_loss: 1.4655 - val_accuracy: 0.4423
# Epoch 15/50
# 63/63 - 32s - loss: 1.1630 - accuracy: 0.5411 - val_loss: 1.5376 - val_accuracy: 0.4038
# Epoch 16/50
# 63/63 - 32s - loss: 1.1662 - accuracy: 0.5571 - val_loss: 1.4640 - val_accuracy: 0.4423
# Epoch 17/50
# 63/63 - 31s - loss: 1.1446 - accuracy: 0.5491 - val_loss: 1.5017 - val_accuracy: 0.4231
# Epoch 18/50
# 63/63 - 31s - loss: 1.1010 - accuracy: 0.6092 - val_loss: 1.3252 - val_accuracy: 0.4808
# Epoch 19/50
# 63/63 - 31s - loss: 0.9988 - accuracy: 0.6373 - val_loss: 1.7467 - val_accuracy: 0.4615
# Epoch 20/50
# 63/63 - 31s - loss: 1.0526 - accuracy: 0.6112 - val_loss: 1.5911 - val_accuracy: 0.3269
# Epoch 21/50
# 63/63 - 31s - loss: 0.9503 - accuracy: 0.6112 - val_loss: 1.5636 - val_accuracy: 0.4231
# Epoch 22/50
# 63/63 - 31s - loss: 0.9112 - accuracy: 0.6553 - val_loss: 1.4043 - val_accuracy: 0.4231
# Epoch 23/50
# 63/63 - 31s - loss: 0.9901 - accuracy: 0.6333 - val_loss: 1.4845 - val_accuracy: 0.4615
# Epoch 24/50
# 63/63 - 31s - loss: 0.8867 - accuracy: 0.6934 - val_loss: 1.4123 - val_accuracy: 0.4038
# Epoch 25/50
# 63/63 - 31s - loss: 0.8422 - accuracy: 0.6814 - val_loss: 1.3306 - val_accuracy: 0.4808
# Epoch 26/50
# 63/63 - 31s - loss: 0.8382 - accuracy: 0.6974 - val_loss: 1.3608 - val_accuracy: 0.4808
# Epoch 27/50
# 63/63 - 31s - loss: 0.8073 - accuracy: 0.7275 - val_loss: 1.4191 - val_accuracy: 0.4423
# Epoch 28/50
# 63/63 - 31s - loss: 0.7636 - accuracy: 0.6874 - val_loss: 1.7426 - val_accuracy: 0.3077
# Epoch 29/50
# 63/63 - 31s - loss: 0.6915 - accuracy: 0.7375 - val_loss: 1.5761 - val_accuracy: 0.4423
# Epoch 30/50
# 63/63 - 31s - loss: 0.6747 - accuracy: 0.7395 - val_loss: 1.9873 - val_accuracy: 0.4231
# Epoch 31/50
# 63/63 - 31s - loss: 0.7003 - accuracy: 0.7335 - val_loss: 1.6084 - val_accuracy: 0.4808
# Epoch 32/50
# 63/63 - 31s - loss: 0.5708 - accuracy: 0.7796 - val_loss: 1.3588 - val_accuracy: 0.4423
# Epoch 33/50
# 63/63 - 31s - loss: 0.6428 - accuracy: 0.7796 - val_loss: 1.3976 - val_accuracy: 0.4423
# Epoch 34/50
# 63/63 - 31s - loss: 0.6141 - accuracy: 0.7976 - val_loss: 1.2701 - val_accuracy: 0.5962
# Epoch 35/50
# 63/63 - 31s - loss: 0.5409 - accuracy: 0.7916 - val_loss: 1.6199 - val_accuracy: 0.4423
# Epoch 36/50
# 63/63 - 31s - loss: 0.5060 - accuracy: 0.8036 - val_loss: 1.5877 - val_accuracy: 0.4808
# Epoch 37/50
# 63/63 - 31s - loss: 0.5872 - accuracy: 0.7776 - val_loss: 1.4753 - val_accuracy: 0.5192
# Epoch 38/50
# 63/63 - 31s - loss: 0.5289 - accuracy: 0.8176 - val_loss: 1.3397 - val_accuracy: 0.5769
# Epoch 39/50
# 63/63 - 31s - loss: 0.5464 - accuracy: 0.8156 - val_loss: 1.3503 - val_accuracy: 0.4615
# Epoch 40/50
# 63/63 - 31s - loss: 0.5156 - accuracy: 0.8216 - val_loss: 1.7313 - val_accuracy: 0.4808
# Epoch 41/50
# 63/63 - 31s - loss: 0.4749 - accuracy: 0.8156 - val_loss: 1.6714 - val_accuracy: 0.4231
# Epoch 42/50
# 63/63 - 31s - loss: 0.6117 - accuracy: 0.7836 - val_loss: 1.5373 - val_accuracy: 0.4423
# Epoch 43/50
# 63/63 - 31s - loss: 0.4804 - accuracy: 0.8257 - val_loss: 1.6517 - val_accuracy: 0.4423
# Epoch 44/50
# 63/63 - 31s - loss: 0.4658 - accuracy: 0.8397 - val_loss: 1.3448 - val_accuracy: 0.5385
# Epoch 45/50
# 63/63 - 31s - loss: 0.5026 - accuracy: 0.8297 - val_loss: 1.4169 - val_accuracy: 0.4808
# Epoch 46/50
# 63/63 - 31s - loss: 0.3493 - accuracy: 0.8697 - val_loss: 2.0106 - val_accuracy: 0.4423
# Epoch 47/50
# 63/63 - 31s - loss: 0.3751 - accuracy: 0.8597 - val_loss: 1.7029 - val_accuracy: 0.4808
# Epoch 48/50
# 63/63 - 31s - loss: 0.4612 - accuracy: 0.8497 - val_loss: 1.9105 - val_accuracy: 0.4423
# Epoch 49/50
# 63/63 - 31s - loss: 0.4632 - accuracy: 0.8397 - val_loss: 1.8948 - val_accuracy: 0.4423
# Epoch 50/50
# 63/63 - 31s - loss: 0.3457 - accuracy: 0.8637 - val_loss: 1.7853 - val_accuracy: 0.4615

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Akurasi Model')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss Model')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
